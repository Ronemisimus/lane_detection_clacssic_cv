# %%
import cv2
from process import process
import os
import sys
import matplotlib.pyplot as plt

img_files = os.listdir("test_images")

w = 10
h = 10
fig = plt.figure(figsize=(20, 10))
columns = 2
rows = 3
for i in range(1, columns*rows +1):
    if i <= len(img_files):
        f_img = "test_images/"+img_files[i-1]
        img = cv2.imread(f_img)
        prev_lines=[]
        img, prev_lines = process(img,prev_lines)

        fig.add_subplot(rows, columns, i)
        plt.title(f_img)
        plt.imshow(img)
plt.show()
# Out:
# /home/ronen/Documents/college/image processing/project-1/code/process.py:152: RuntimeWarning: divide by zero encountered in long_scalars
#   base_mult = (height-y2)/line_base[0]
# /home/ronen/Documents/college/image processing/project-1/code/process.py:153: RuntimeWarning: invalid value encountered in multiply
#   base_point = np.array([y2,x2])+base_mult*line_base
